# %% [markdown]
# <div dir="rtl" style="font-family:'Vazirmatn','IRANSans',Tahoma,Arial,sans-serif; font-size:17px; line-height:1.9; color:#33404d; max-width:760px; margin:0 auto;">
# <h2 style="color:#306998; font-size:23px; font-weight:700; border-bottom:1px solid #EAF2F8; padding-bottom:10px; margin:0 0 18px;">📖 loc — انتخاب با برچسب</h2>
# <p style="margin:0 0 14px; text-align:justify;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">loc</code> ابزار دسترسی <strong>برچسب‌محور</strong> (label-based) است. برای انتخاب ردیف، ستون، یا هر دو با هم از نام/برچسب استفاده می‌کند — نه از موقعیت عددی.</p>
# <div style="background:#EAF2F8; border-right:3px solid #4B8BBE; border-radius:6px; padding:12px 16px; margin:18px 0; text-align:right; font-weight:600; font-size:18px; color:#306998;">قانون loc: هر آنچه داخل <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">loc</code> می‌گذارید باید <strong>برچسب</strong> باشد — نام ستون، برچسب index، یا لیستی از آن‌ها.</div>
# <div style="background:#F8F9FB; border-right:3px solid #4B8BBE; border-radius:6px; padding:12px 16px; margin:0 0 26px;">
#     <div style="font-weight:700; color:#306998; margin-bottom:6px;">🧠 مدل ذهنی</div>
#     <p style="margin:0; text-align:right;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc[برچسب_ردیف, برچسب_ستون]</code> — اگر فقط یک بخش بدهید، آن محور را انتخاب می‌کند.</p>
#   </div>
# <hr style="border:none; border-top:1px solid #E6E9ED; margin:22px 0;">
# <h3 style="color:#306998; font-size:18px; margin:28px 0 6px;">🏷️ یک ردیف با loc</h3><p style="margin:0 0 12px; font-size:14px; color:#78828C;">برچسب index</p>
# <p style="margin:0 0 14px; text-align:justify;">بعد از <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.set_index("model")</code>، یک ردیف: <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc["BMW X6"]</code> → <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">Series</code> (index = نام ستون‌ها).</p>
# <table dir="rtl" style="width:100%; border-collapse:collapse; margin:0 0 16px; font-size:15px;">
#     <thead><tr style="background:#EAF2F8;"><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">سینتکس</th><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">خروجی</th><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">نوع</th></tr></thead>
#     <tbody><tr><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc["BMW X6"]</code></td><td style="padding:10px 12px; border:1px solid #E6E9ED;">یک ردیف</td><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">Series</code></td></tr><tr style="background:#FAFBFC;"><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc["Tiba"]</code></td><td style="padding:10px 12px; border:1px solid #E6E9ED;">یک ردیف دیگر</td><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">Series</code></td></tr></tbody>
#   </table>
# <p style="margin:10px 0 4px; text-align:justify;">DataFrame خودروها را با <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">set_index("model")</code> آماده کنید. ردیف <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">"Peugeot 206"</code> را با <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">loc</code> انتخاب کنید.</p>
#   <!-- کد را خودت بنویس -->
# </div>

# %% [markdown]
# <div dir="rtl" style="font-family:'Vazirmatn','IRANSans',Tahoma,Arial,sans-serif; font-size:17px; line-height:1.9; color:#33404d; max-width:760px; margin:0 auto;">
# <h3 style="color:#306998; font-size:18px; margin:28px 0 6px;">🏷️ چند ردیف و slice برچسبی</h3><p style="margin:0 0 12px; font-size:14px; color:#78828C;">لیست و بازه</p>
# <p style="margin:0 0 14px; text-align:justify;">چند ردیف با لیست برچسب: <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc[["Peykan", "Tiba", "BMW X6"]]</code> → <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">DataFrame</code></p>
# <p style="margin:0 0 14px; text-align:justify;">بازه برچسبی: <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc["Peugeot 206":"Tiba"]</code> — هر دو端 <strong>شامل</strong> می‌شوند (برخلاف slice موقعیتی).</p>
# <div style="background:#FFF8F0; border-right:3px solid #E6A23C; border-radius:6px; padding:12px 16px; margin:18px 0;">
#     <div style="font-weight:700; color:#B7791F; margin-bottom:6px;">⚠️ اشتباه رایج</div>
#     <p style="margin:0; text-align:right;">slice برچسبی فقط وقتی معنا دارد که index <strong>مرتب</strong> باشد. اگر index نامرتب است، نتیجه ممکن است غیرمنتظره باشد.</p>
#   </div>
# <p style="margin:10px 0 4px; text-align:justify;">سه خودرو <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">"Peykan"</code>، <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">"Tiba"</code> و <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">"BMW X6"</code> را با لیست <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">loc</code> انتخاب کنید. سپس بازه <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">"Peugeot 206":"Tiba"</code> را امتحان کنید.</p>
#   <!-- کد را خودت بنویس -->
# </div>

# %% [markdown]
# <div dir="rtl" style="font-family:'Vazirmatn','IRANSans',Tahoma,Arial,sans-serif; font-size:17px; line-height:1.9; color:#33404d; max-width:760px; margin:0 auto;">
# <h3 style="color:#306998; font-size:18px; margin:28px 0 6px;">📋 انتخاب ستون با loc</h3><p style="margin:0 0 12px; font-size:14px; color:#78828C;">برچسب ستون</p>
# <p style="margin:0 0 14px; text-align:justify;">یک ستون: <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc[:, "HP"]</code> — <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">:</code> یعنی «همه‌ی ردیف‌ها».</p>
# <p style="margin:0 0 14px; text-align:justify;">چند ستون: <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc[:, ["Color", "price"]]</code> → <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">DataFrame</code></p>
# <table dir="rtl" style="width:100%; border-collapse:collapse; margin:0 0 16px; font-size:15px;">
#     <thead><tr style="background:#EAF2F8;"><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">سینتکس</th><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">معنا</th></tr></thead>
#     <tbody><tr><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc[:, "HP"]</code></td><td style="padding:10px 12px; border:1px solid #E6E9ED;">ستون HP، همه ردیف‌ها</td></tr><tr style="background:#FAFBFC;"><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc[:, ["HP","price"]]</code></td><td style="padding:10px 12px; border:1px solid #E6E9ED;">دو ستون، همه ردیف‌ها</td></tr></tbody>
#   </table>
# <p style="margin:10px 0 4px; text-align:justify;">با <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">loc</code> فقط ستون‌های <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">"Color"</code> و <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">"price"</code> را برای تمام ردیف‌ها انتخاب کنید.</p>
#   <!-- کد را خودت بنویس -->
# </div>

# %% [markdown]
# <div dir="rtl" style="font-family:'Vazirmatn','IRANSans',Tahoma,Arial,sans-serif; font-size:17px; line-height:1.9; color:#33404d; max-width:760px; margin:0 auto;">
# <h3 style="color:#306998; font-size:18px; margin:28px 0 6px;">🎯 ترکیب ردیف و ستون</h3><p style="margin:0 0 12px; font-size:14px; color:#78828C;">یک سلول تا یک زیرجدول</p>
# <p style="margin:0 0 14px; text-align:justify;">یک مقدار (اسکالر): <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc["BMW X6", "price"]</code></p>
# <p style="margin:0 0 14px; text-align:justify;">یک ردیف، چند ستون: <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc["BMW X6", ["Color", "price"]]</code> → <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">Series</code></p>
# <p style="margin:0 0 14px; text-align:justify;">چند ردیف، چند ستون: <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc[["Peykan", "BMW X6"], ["Color", "HP"]]</code> → <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">DataFrame</code></p>
# <table dir="rtl" style="width:100%; border-collapse:collapse; margin:0 0 16px; font-size:15px;">
#     <thead><tr style="background:#EAF2F8;"><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">هدف</th><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">سینتکس</th><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">خروجی</th></tr></thead>
#     <tbody><tr><td style="padding:10px 12px; border:1px solid #E6E9ED;">یک سلول</td><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc["BMW X6", "price"]</code></td><td style="padding:10px 12px; border:1px solid #E6E9ED;">اسکالر</td></tr><tr style="background:#FAFBFC;"><td style="padding:10px 12px; border:1px solid #E6E9ED;">یک ردیف، چند ستون</td><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc["BMW X6", ["Color","price"]]</code></td><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">Series</code></td></tr><tr><td style="padding:10px 12px; border:1px solid #E6E9ED;">زیرجدول</td><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc[["Peykan","BMW X6"], ["HP","price"]]</code></td><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">DataFrame</code></td></tr></tbody>
#   </table>
# <p style="margin:10px 0 4px; text-align:justify;">قیمت <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">"Tiba"</code> را به‌صورت اسکالر بگیرید. سپس زیرجدولی از <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">"Peykan"</code> و <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">"BMW X6"</code> با ستون‌های <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">"HP"</code> و <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">"price"</code> بسازید.</p>
#   <!-- کد را خودت بنویس -->
# </div>

# %% [markdown]
# <div dir="rtl" style="font-family:'Vazirmatn','IRANSans',Tahoma,Arial,sans-serif; font-size:17px; line-height:1.9; color:#33404d; max-width:760px; margin:0 auto;">
# <h3 style="color:#306998; font-size:18px; margin:28px 0 6px;">✅ جمع‌بندی فصل</h3><p style="margin:0 0 12px; font-size:14px; color:#78828C;">loc</p>
# <table dir="rtl" style="width:100%; border-collapse:collapse; margin:0 0 16px; font-size:15px;">
#     <thead><tr style="background:#EAF2F8;"><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">کاربرد</th><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">الگو</th></tr></thead>
#     <tbody><tr><td style="padding:10px 12px; border:1px solid #E6E9ED;">یک ردیف</td><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc["label"]</code></td></tr><tr style="background:#FAFBFC;"><td style="padding:10px 12px; border:1px solid #E6E9ED;">چند ردیف</td><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc[["l1","l2"]]</code></td></tr><tr><td style="padding:10px 12px; border:1px solid #E6E9ED;">بازه برچسبی</td><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc["start":"end"]</code></td></tr><tr style="background:#FAFBFC;"><td style="padding:10px 12px; border:1px solid #E6E9ED;">ستون(ها)</td><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc[:, "col"]</code> یا <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc[:, ["c1","c2"]]</code></td></tr><tr><td style="padding:10px 12px; border:1px solid #E6E9ED;">سلول / زیرجدول</td><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc[row, col]</code></td></tr></tbody>
#   </table>
# <p style="margin:0 0 14px; text-align:justify;">فصل بعد: <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">iloc</code> — همان کارها، اما با موقعیت عددی.</p>
# </div>
