# %%
import pandas as pd
import numpy as np
from scipy.stats import mode
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("weather.csv")

# %%
df
# Out:
#                  time  temperature_2m (°C)  relative_humidity_2m (%)  \
# 0    2024-11-03T00:00                  NaN                        56
# 1    2024-11-03T01:00                 12.4                        57
# 2    2024-11-03T02:00                 12.4                        58
# 3    2024-11-03T03:00                 12.7                        55
# 4    2024-11-03T04:00                 13.8                        52
# ..                ...                  ...                       ...
# 163  2024-11-09T19:00                  6.7                        70
# 164  2024-11-09T20:00                  6.4                        72
# 165  2024-11-09T21:00                  6.2                        73
# 166  2024-11-09T22:00                  6.3                        71
# 167  2024-11-09T23:00                  6.6                        67
#
#      dew_point_2m (°C)  rain (mm)  showers (mm)  snowfall (cm)  \
# 0                  3.8        0.0           0.0            0.0
# ...

# %%
df.fillna(df["temperature_2m (°C)"].mean(), inplace=True)

# %%
df
# Out:
#                  time  temperature_2m (°C)  relative_humidity_2m (%)  \
# 0    2024-11-03T00:00            13.383832                        56
# 1    2024-11-03T01:00            12.400000                        57
# 2    2024-11-03T02:00            12.400000                        58
# 3    2024-11-03T03:00            12.700000                        55
# 4    2024-11-03T04:00            13.800000                        52
# ..                ...                  ...                       ...
# 163  2024-11-09T19:00             6.700000                        70
# 164  2024-11-09T20:00             6.400000                        72
# 165  2024-11-09T21:00             6.200000                        73
# 166  2024-11-09T22:00             6.300000                        71
# 167  2024-11-09T23:00             6.600000                        67
#
#      dew_point_2m (°C)  rain (mm)  showers (mm)  snowfall (cm)  \
# 0                  3.8        0.0           0.0            0.0
# ...

# %%
df["wind_speed_180m (km/h)"] = pd.to_numeric(df["wind_speed_180m (km/h)"] , errors="coerce")

# %%
df
# Out:
#                  time  temperature_2m (°C)  relative_humidity_2m (%)  \
# 0    2024-11-03T00:00            13.383832                        56
# 1    2024-11-03T01:00            12.400000                        57
# 2    2024-11-03T02:00            12.400000                        58
# 3    2024-11-03T03:00            12.700000                        55
# 4    2024-11-03T04:00            13.800000                        52
# ..                ...                  ...                       ...
# 163  2024-11-09T19:00             6.700000                        70
# 164  2024-11-09T20:00             6.400000                        72
# 165  2024-11-09T21:00             6.200000                        73
# 166  2024-11-09T22:00             6.300000                        71
# 167  2024-11-09T23:00             6.600000                        67
#
#      dew_point_2m (°C)  rain (mm)  showers (mm)  snowfall (cm)  \
# 0                  3.8        0.0           0.0            0.0
# ...

# %%
plt.boxplot(df["temperature_2m (°C)"].values)
plt.show()

# %%
mode_last = mode(df["wind_speed_180m (km/h)"])
print(mode_last)
mode_last[0]
# Out:
# ModeResult(mode=3.3, count=6)
# 3.3

# %%
df
# Out:
#                  time  temperature_2m (°C)  relative_humidity_2m (%)  \
# 0    2024-11-03T00:00            13.383832                        56
# 1    2024-11-03T01:00            12.400000                        57
# 2    2024-11-03T02:00            12.400000                        58
# 3    2024-11-03T03:00            12.700000                        55
# 4    2024-11-03T04:00            13.800000                        52
# ..                ...                  ...                       ...
# 163  2024-11-09T19:00             6.700000                        70
# 164  2024-11-09T20:00             6.400000                        72
# 165  2024-11-09T21:00             6.200000                        73
# 166  2024-11-09T22:00             6.300000                        71
# 167  2024-11-09T23:00             6.600000                        67
#
#      dew_point_2m (°C)  rain (mm)  showers (mm)  snowfall (cm)  \
# 0                  3.8        0.0           0.0            0.0
# ...

# %%
df.fillna(mode_last[0], inplace=True)

# %%
df
# Out:
#                  time  temperature_2m (°C)  relative_humidity_2m (%)  \
# 0    2024-11-03T00:00            13.383832                        56
# 1    2024-11-03T01:00            12.400000                        57
# 2    2024-11-03T02:00            12.400000                        58
# 3    2024-11-03T03:00            12.700000                        55
# 4    2024-11-03T04:00            13.800000                        52
# ..                ...                  ...                       ...
# 163  2024-11-09T19:00             6.700000                        70
# 164  2024-11-09T20:00             6.400000                        72
# 165  2024-11-09T21:00             6.200000                        73
# 166  2024-11-09T22:00             6.300000                        71
# 167  2024-11-09T23:00             6.600000                        67
#
#      dew_point_2m (°C)  rain (mm)  showers (mm)  snowfall (cm)  \
# 0                  3.8        0.0           0.0            0.0
# ...

# %%
scaler = StandardScaler()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 2
#       1 scaler = StandardScaler()
# ----> 2 df["relative_humidity_2m (%)"] = scaler.fit_transform(df["relative_humidity_2m (%)"].values.reshape(-1, 1))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# ...

# %%
df
# Out:
#                  time  temperature_2m (°C) relative_humidity_2m (%)  \
# 0    2024-11-03T00:00            13.383832         StandardScaler()
# 1    2024-11-03T01:00            12.400000         StandardScaler()
# 2    2024-11-03T02:00            12.400000         StandardScaler()
# 3    2024-11-03T03:00            12.700000         StandardScaler()
# 4    2024-11-03T04:00            13.800000         StandardScaler()
# ..                ...                  ...                      ...
# 163  2024-11-09T19:00             6.700000         StandardScaler()
# 164  2024-11-09T20:00             6.400000         StandardScaler()
# 165  2024-11-09T21:00             6.200000         StandardScaler()
# 166  2024-11-09T22:00             6.300000         StandardScaler()
# 167  2024-11-09T23:00             6.600000         StandardScaler()
#
#      dew_point_2m (°C)  rain (mm)  showers (mm)  snowfall (cm)  \
# 0                  3.8        0.0           0.0            0.0
# ...

# %%
df["relative_humidity_2m (%)"] = scaler.fit_transform(df["relative_humidity_2m (%)"].values.reshape(-1, 1))

# %%
df.fillna(100, inplace=True)
