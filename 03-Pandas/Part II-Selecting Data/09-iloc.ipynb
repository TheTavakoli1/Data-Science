# %% [markdown]
# <div dir="rtl" style="font-family:'Vazirmatn','IRANSans',Tahoma,Arial,sans-serif; font-size:17px; line-height:1.9; color:#33404d; max-width:760px; margin:0 auto;">
# <h2 style="color:#306998; font-size:23px; font-weight:700; border-bottom:1px solid #EAF2F8; padding-bottom:10px; margin:0 0 18px;">📖 iloc — انتخاب با موقعیت</h2>
# <p style="margin:0 0 14px; text-align:justify;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">iloc</code> ابزار دسترسی <strong>موقعیت‌محور</strong> (position-based) است. همیشه از اعداد صحیح استفاده می‌کند — برچسب index اهمیتی ندارد.</p>
# <div style="background:#EAF2F8; border-right:3px solid #4B8BBE; border-radius:6px; padding:12px 16px; margin:18px 0; text-align:right; font-weight:600; font-size:18px; color:#306998;">قانون iloc: هر آنچه داخل <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">iloc</code> می‌گذارید باید <strong>موقعیت عددی</strong> باشد — ۰، ۱، ۲، … یا slice مثل <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">1:4</code>.</div>
# <div style="background:#F8F9FB; border-right:3px solid #4B8BBE; border-radius:6px; padding:12px 16px; margin:0 0 26px;">
#     <div style="font-weight:700; color:#306998; margin-bottom:6px;">🧠 مدل ذهنی</div>
#     <p style="margin:0; text-align:right;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">iloc</code> = «ردیف nام» یا «ستون nام» — مثل اندیس آرایه، از صفر شروع می‌شود.</p>
#   </div>
# <hr style="border:none; border-top:1px solid #E6E9ED; margin:22px 0;">
# <h3 style="color:#306998; font-size:18px; margin:28px 0 6px;">🔢 یک ردیف با iloc</h3><p style="margin:0 0 12px; font-size:14px; color:#78828C;">موقعیت ۰، ۱، ۲، …</p>
# <p style="margin:0 0 14px; text-align:justify;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.iloc[0]</code> → اولین ردیف (موقعیت ۰) → <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">Series</code></p>
# <p style="margin:0 0 14px; text-align:justify;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.iloc[2]</code> → سومین ردیف → <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">Series</code> — حتی اگر index برچسب دیگری داشته باشد.</p>
# <table dir="rtl" style="width:100%; border-collapse:collapse; margin:0 0 16px; font-size:15px;">
#     <thead><tr style="background:#EAF2F8;"><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">سینتکس</th><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">معنا</th><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">نوع</th></tr></thead>
#     <tbody><tr><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.iloc[0]</code></td><td style="padding:10px 12px; border:1px solid #E6E9ED;">اولین ردیف</td><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">Series</code></td></tr><tr style="background:#FAFBFC;"><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.iloc[-1]</code></td><td style="padding:10px 12px; border:1px solid #E6E9ED;">آخرین ردیف</td><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">Series</code></td></tr></tbody>
#   </table>
# <p style="margin:10px 0 4px; text-align:justify;">بدون <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">set_index</code>، ردیف اول و سوم را با <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">iloc</code> بگیرید. سپس index را عوض کنید و دوباره <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">iloc[0]</code> را اجرا کنید — همان ردیف فیزیکی اول است.</p>
#   <!-- کد را خودت بنویس -->
# </div>

# %% [markdown]
# <div dir="rtl" style="font-family:'Vazirmatn','IRANSans',Tahoma,Arial,sans-serif; font-size:17px; line-height:1.9; color:#33404d; max-width:760px; margin:0 auto;">
# <h3 style="color:#306998; font-size:18px; margin:28px 0 6px;">🔢 چند ردیف و slice موقعیتی</h3><p style="margin:0 0 12px; font-size:14px; color:#78828C;">لیست و بازه</p>
# <p style="margin:0 0 14px; text-align:justify;">چند ردیف: <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.iloc[[0, 2, 4]]</code> → <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">DataFrame</code></p>
# <p style="margin:0 0 14px; text-align:justify;">بازه موقعیتی: <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.iloc[1:4]</code> — ردیف‌های ۱، ۲، ۳ (ردیف ۴ <strong>شامل نمی‌شود</strong>).</p>
# <div style="background:#FFF8F0; border-right:3px solid #E6A23C; border-radius:6px; padding:12px 16px; margin:18px 0;">
#     <div style="font-weight:700; color:#B7791F; margin-bottom:6px;">⚠️ اشتباه رایج</div>
#     <p style="margin:0; text-align:right;">در <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">iloc[1:4]</code> انتهای بازه exclusive است (مثل slice پایتون). در <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">loc</code> با برچسب، هر دو端 inclusive است.</p>
#   </div>
# <p style="margin:10px 0 4px; text-align:justify;">با <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">iloc</code> ردیف‌های ۰، ۲ و ۴ را با لیست انتخاب کنید. سپس بازه <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">1:4</code> را امتحان کنید و تعداد ردیف خروجی را بشمارید.</p>
#   <!-- کد را خودت بنویس -->
# </div>

# %% [markdown]
# <div dir="rtl" style="font-family:'Vazirmatn','IRANSans',Tahoma,Arial,sans-serif; font-size:17px; line-height:1.9; color:#33404d; max-width:760px; margin:0 auto;">
# <h3 style="color:#306998; font-size:18px; margin:28px 0 6px;">📋 انتخاب ستون با iloc</h3><p style="margin:0 0 12px; font-size:14px; color:#78828C;">موقعیت ستون</p>
# <p style="margin:0 0 14px; text-align:justify;">یک ستون (همه ردیف‌ها): <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.iloc[:, 1]</code> — ستون دوم (موقعیت ۱).</p>
# <p style="margin:0 0 14px; text-align:justify;">چند ستون: <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.iloc[:, [0, 2, 4]]</code> → <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">DataFrame</code></p>
# <table dir="rtl" style="width:100%; border-collapse:collapse; margin:0 0 16px; font-size:15px;">
#     <thead><tr style="background:#EAF2F8;"><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">سینتکس</th><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">معنا</th></tr></thead>
#     <tbody><tr><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.iloc[:, 0]</code></td><td style="padding:10px 12px; border:1px solid #E6E9ED;">ستون اول</td></tr><tr style="background:#FAFBFC;"><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.iloc[:, [0, 2]]</code></td><td style="padding:10px 12px; border:1px solid #E6E9ED;">ستون اول و سوم</td></tr></tbody>
#   </table>
# <p style="margin:10px 0 4px; text-align:justify;">ستون‌های اول، سوم و پنجم را با <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">iloc</code> انتخاب کنید (با لیست موقعیت).</p>
#   <!-- کد را خودت بنویس -->
# </div>

# %% [markdown]
# <div dir="rtl" style="font-family:'Vazirmatn','IRANSans',Tahoma,Arial,sans-serif; font-size:17px; line-height:1.9; color:#33404d; max-width:760px; margin:0 auto;">
# <h3 style="color:#306998; font-size:18px; margin:28px 0 6px;">🎯 ترکیب ردیف و ستون</h3><p style="margin:0 0 12px; font-size:14px; color:#78828C;">زیرجدول موقعیتی</p>
# <p style="margin:0 0 14px; text-align:justify;">یک سلول: <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.iloc[1, 4]</code> — ردیف ۱، ستون ۴.</p>
# <p style="margin:0 0 14px; text-align:justify;">یک ردیف، چند ستون: <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.iloc[1, [0, 4]]</code> → <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">Series</code></p>
# <p style="margin:0 0 14px; text-align:justify;">زیرجدول: <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.iloc[[0, 2], [1, 3]]</code> → <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">DataFrame</code></p>
# <p style="margin:0 0 14px; text-align:justify;">زنجیره‌ای (ستون اول، ردیف بعد): <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df[["model", "price"]].iloc[0]</code> — ابتدا ستون با براکت، سپس ردیف با <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">iloc</code>.</p>
# <p style="margin:10px 0 4px; text-align:justify;">با <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">iloc</code> مقدار ردیف ۲ و ستون ۳ را بگیرید. سپس زیرجدول ردیف‌های ۰ و ۲ با ستون‌های ۱ و ۲ بسازید.</p>
#   <!-- کد را خودت بنویس -->
# </div>

# %% [markdown]
# <div dir="rtl" style="font-family:'Vazirmatn','IRANSans',Tahoma,Arial,sans-serif; font-size:17px; line-height:1.9; color:#33404d; max-width:760px; margin:0 auto;">
# <h3 style="color:#306998; font-size:18px; margin:28px 0 6px;">⚖️ loc در برابر iloc</h3><p style="margin:0 0 12px; font-size:14px; color:#78828C;">جدول مقایسه</p>
# <table dir="rtl" style="width:100%; border-collapse:collapse; margin:0 0 16px; font-size:15px;">
#     <thead><tr style="background:#EAF2F8;"><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">ویژگی</th><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">loc</code></th><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">iloc</code></th></tr></thead>
#     <tbody><tr><td style="padding:10px 12px; border:1px solid #E6E9ED;">بر اساس</td><td style="padding:10px 12px; border:1px solid #E6E9ED;">برچسب</td><td style="padding:10px 12px; border:1px solid #E6E9ED;">موقعیت عددی</td></tr><tr style="background:#FAFBFC;"><td style="padding:10px 12px; border:1px solid #E6E9ED;">یک ردیف</td><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc["label"]</code></td><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.iloc[0]</code></td></tr><tr><td style="padding:10px 12px; border:1px solid #E6E9ED;">چند ردیف</td><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc[["l1","l2"]]</code></td><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.iloc[[0,1]]</code></td></tr><tr style="background:#FAFBFC;"><td style="padding:10px 12px; border:1px solid #E6E9ED;">slice</td><td style="padding:10px 12px; border:1px solid #E6E9ED;">هر دو端 inclusive</td><td style="padding:10px 12px; border:1px solid #E6E9ED;">انتها exclusive</td></tr><tr><td style="padding:10px 12px; border:1px solid #E6E9ED;">ستون</td><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc[:, "col"]</code></td><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.iloc[:, 0]</code></td></tr></tbody>
#   </table>
# <p style="margin:10px 0 4px; text-align:justify;">برای همان DataFrame با <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">set_index("model")</code>، ردیف <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">"BMW X6"</code> را با <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">loc</code> و ردیف اول را با <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">iloc</code> بگیرید. آیا همیشه یکسان‌اند؟</p>
#   <!-- کد را خودت بنویس -->
# </div>

# %% [markdown]
# <div dir="rtl" style="font-family:'Vazirmatn','IRANSans',Tahoma,Arial,sans-serif; font-size:17px; line-height:1.9; color:#33404d; max-width:760px; margin:0 auto;">
# <h3 style="color:#306998; font-size:18px; margin:28px 0 6px;">✅ جمع‌بندی فصل</h3><p style="margin:0 0 12px; font-size:14px; color:#78828C;">iloc</p>
# <p style="margin:0 0 14px; text-align:justify;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">iloc</code> برای وقتی که موقعیت را می‌دانیم؛ <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">loc</code> برای وقتی که برچسب را می‌دانیم. در فصل بعد <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">at</code> و <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">iat</code> را برای دسترسی سریع به <strong>یک سلول</strong> می‌بینیم.</p>
# </div>
