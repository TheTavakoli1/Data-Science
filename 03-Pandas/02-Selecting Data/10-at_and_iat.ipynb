# %% [markdown]
# <div dir="rtl" style="font-family:'Vazirmatn','IRANSans',Tahoma,Arial,sans-serif; font-size:17px; line-height:1.9; color:#33404d; max-width:760px; margin:0 auto;">
# <h2 style="color:#306998; font-size:23px; font-weight:700; border-bottom:1px solid #EAF2F8; padding-bottom:10px; margin:0 0 18px;">📖 at و iat — دسترسی به یک سلول</h2>
# <p style="margin:0 0 14px; text-align:justify;">وقتی فقط <strong>یک مقدار</strong> (اسکالر) از جدول نیاز داریم، <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">loc</code> و <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">iloc</code> کار می‌کنند اما <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">at</code> و <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">iat</code> برای این کار بهینه‌تر و خواناترند.</p>
# <div style="background:#EAF2F8; border-right:3px solid #4B8BBE; border-radius:6px; padding:12px 16px; margin:18px 0; text-align:right; font-weight:600; font-size:18px; color:#306998;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">at</code> = برچسب (مثل loc) — <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">iat</code> = موقعیت (مثل iloc). هر دو فقط برای <strong>یک سلول</strong>.</div>
# <div style="background:#F8F9FB; border-right:3px solid #4B8BBE; border-radius:6px; padding:12px 16px; margin:0 0 26px;">
#     <div style="font-weight:700; color:#306998; margin-bottom:6px;">🧠 مدل ذهنی</div>
#     <p style="margin:0; text-align:right;">اگر خروجی شما باید یک عدد یا رشته‌ی تکی باشد (نه Series)، <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">at</code>/<code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">iat</code> انتخاب بهتری‌اند.</p>
#   </div>
# <hr style="border:none; border-top:1px solid #E6E9ED; margin:22px 0;">
# <h3 style="color:#306998; font-size:18px; margin:28px 0 6px;">🏷️ at — سلول با برچسب</h3><p style="margin:0 0 12px; font-size:14px; color:#78828C;">label-based scalar access</p>
# <p style="margin:0 0 14px; text-align:justify;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.at["BMW X6", "price"]</code> — قیمت خودرو BMW X6 (بعد از <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">set_index("model")</code>).</p>
# <table dir="rtl" style="width:100%; border-collapse:collapse; margin:0 0 16px; font-size:15px;">
#     <thead><tr style="background:#EAF2F8;"><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">سینتکس</th><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">معنا</th><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">خروجی</th></tr></thead>
#     <tbody><tr><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.at["BMW X6", "price"]</code></td><td style="padding:10px 12px; border:1px solid #E6E9ED;">یک سلول برچسبی</td><td style="padding:10px 12px; border:1px solid #E6E9ED;">اسکالر</td></tr><tr style="background:#FAFBFC;"><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.loc["BMW X6", "price"]</code></td><td style="padding:10px 12px; border:1px solid #E6E9ED;">همان سلول با loc</td><td style="padding:10px 12px; border:1px solid #E6E9ED;">اسکالر</td></tr></tbody>
#   </table>
# <p style="margin:10px 0 4px; text-align:justify;">با <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">at</code> رنگ <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">"Tiba"</code> و قدرت <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">"BMW X6"</code> را بخوانید.</p>
#   <!-- کد را خودت بنویس -->
# </div>

# %% [markdown]
# <div dir="rtl" style="font-family:'Vazirmatn','IRANSans',Tahoma,Arial,sans-serif; font-size:17px; line-height:1.9; color:#33404d; max-width:760px; margin:0 auto;">
# <h3 style="color:#306998; font-size:18px; margin:28px 0 6px;">🔢 iat — سلول با موقعیت</h3><p style="margin:0 0 12px; font-size:14px; color:#78828C;">position-based scalar access</p>
# <p style="margin:0 0 14px; text-align:justify;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.iat[0, 4]</code> — مقدار ردیف ۰، ستون ۴ (موقعیت‌ها، نه نام).</p>
# <table dir="rtl" style="width:100%; border-collapse:collapse; margin:0 0 16px; font-size:15px;">
#     <thead><tr style="background:#EAF2F8;"><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">سینتکس</th><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">معنا</th></tr></thead>
#     <tbody><tr><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.iat[1, 2]</code></td><td style="padding:10px 12px; border:1px solid #E6E9ED;">ردیف ۱، ستون ۲</td></tr><tr style="background:#FAFBFC;"><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">df.iloc[1, 2]</code></td><td style="padding:10px 12px; border:1px solid #E6E9ED;">معادل با iloc برای یک سلول</td></tr></tbody>
#   </table>
# <p style="margin:10px 0 4px; text-align:justify;">با <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">iat</code> مقدار ردیف ۰ و ستون ۰ و همچنین ردیف ۳ و ستون ۲ را بخوانید.</p>
#   <!-- کد را خودت بنویس -->
# </div>

# %% [markdown]
# <div dir="rtl" style="font-family:'Vazirmatn','IRANSans',Tahoma,Arial,sans-serif; font-size:17px; line-height:1.9; color:#33404d; max-width:760px; margin:0 auto;">
# <h3 style="color:#306998; font-size:18px; margin:28px 0 6px;">⚖️ چه زمانی at/iat؟</h3><p style="margin:0 0 12px; font-size:14px; color:#78828C;">مقایسه با loc/iloc</p>
# <table dir="rtl" style="width:100%; border-collapse:collapse; margin:0 0 16px; font-size:15px;">
#     <thead><tr style="background:#EAF2F8;"><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">ابزار</th><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">ورودی</th><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">خروجی</th><th style="padding:10px 12px; text-align:right; color:#306998; border:1px solid #E6E9ED;">بهترین کاربرد</th></tr></thead>
#     <tbody><tr><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">at</code></td><td style="padding:10px 12px; border:1px solid #E6E9ED;">برچسب ردیف + ستون</td><td style="padding:10px 12px; border:1px solid #E6E9ED;">اسکالر</td><td style="padding:10px 12px; border:1px solid #E6E9ED;">خواندن/نوشتن یک سلول</td></tr><tr style="background:#FAFBFC;"><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">iat</code></td><td style="padding:10px 12px; border:1px solid #E6E9ED;">موقعیت ردیف + ستون</td><td style="padding:10px 12px; border:1px solid #E6E9ED;">اسکالر</td><td style="padding:10px 12px; border:1px solid #E6E9ED;">خواندن/نوشتن یک سلول</td></tr><tr><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">loc</code></td><td style="padding:10px 12px; border:1px solid #E6E9ED;">برچسب (انعطاف‌پذیر)</td><td style="padding:10px 12px; border:1px solid #E6E9ED;">اسکالر تا DataFrame</td><td style="padding:10px 12px; border:1px solid #E6E9ED;">ردیف/ستون/زیرجدول</td></tr><tr style="background:#FAFBFC;"><td style="padding:10px 12px; border:1px solid #E6E9ED;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">iloc</code></td><td style="padding:10px 12px; border:1px solid #E6E9ED;">موقعیت (انعطاف‌پذیر)</td><td style="padding:10px 12px; border:1px solid #E6E9ED;">اسکالر تا DataFrame</td><td style="padding:10px 12px; border:1px solid #E6E9ED;">ردیف/ستون/زیرجدول</td></tr></tbody>
#   </table>
# <div style="background:#FFF8F0; border-right:3px solid #E6A23C; border-radius:6px; padding:12px 16px; margin:18px 0;">
#     <div style="font-weight:700; color:#B7791F; margin-bottom:6px;">⚠️ محدودیت</div>
#     <p style="margin:0; text-align:right;"><code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">at</code> و <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">iat</code> فقط برای <strong>یک سلول</strong> طراحی شده‌اند. برای انتخاب چند ردیف یا ستون از <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">loc</code>/<code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">iloc</code> استفاده کنید.</p>
#   </div>
# <p style="margin:10px 0 4px; text-align:justify;">همان سلول را یک‌بار با <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">at</code> و یک‌بار با <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">loc</code> بخوانید. آیا خروجی یکسان است؟</p>
#   <!-- کد را خودت بنویس -->
# </div>

# %% [markdown]
# <div dir="rtl" style="font-family:'Vazirmatn','IRANSans',Tahoma,Arial,sans-serif; font-size:17px; line-height:1.9; color:#33404d; max-width:760px; margin:0 auto;">
# <h3 style="color:#306998; font-size:18px; margin:28px 0 6px;">✅ جمع‌بندی فصل</h3><p style="margin:0 0 12px; font-size:14px; color:#78828C;">at و iat</p>
# <p style="margin:0 0 14px; text-align:justify;">فصل بعد: <code dir="ltr" style="unicode-bidi:isolate; background:#EFF3F7; color:#4B8BBE; padding:1px 6px; border-radius:4px; font-family:Consolas,'Fira Code',monospace; font-size:14px;">Boolean Indexing</code> — انتخاب ردیف‌ها بر اساس <strong>شرط</strong> (مثلاً HP بیشتر از ۱۰۰).</p>
# </div>
